# %%
import pandas as pd
import datetime as dt
import pandas_datareader as pdr

start = dt.datetime(2021, 1, 1)
end = dt.datetime(2021, 5, 19)
df_2330 = pdr.DataReader('2330.TW', 'yahoo', start=start, end=end)
df_2454 = pdr.DataReader('2454.TW', 'yahoo', start=start, end=end)
df_2330.head()
# Out:
#              High    Low   Open  Close      Volume   Adj Close
# Date
# 2021-01-04  540.0  528.0  530.0  536.0  38770328.0  533.814026
# 2021-01-05  542.0  535.0  536.0  542.0  34411866.0  539.789551
# 2021-01-06  555.0  541.0  555.0  549.0  53030554.0  546.760986
# 2021-01-07  570.0  553.0  554.0  565.0  51166782.0  562.695740
# 2021-01-08  580.0  571.0  580.0  580.0  59563555.0  577.634583

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 6))
plt.plot(df_2330.Close, label='TSMC')
plt.plot(df_2454.Close, label='MediaTek')
plt.title('TSMC vs MediaTek', loc='center')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True, axis='y')
plt.legend()
plt.show()

# %%
import mplfinance as mpf

mpf.plot(df_2330, type='candle', mav=10, volume=True)
